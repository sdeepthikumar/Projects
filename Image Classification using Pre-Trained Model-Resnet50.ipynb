# %%
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input,decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
from IPython.display import Image

# %%
model = ResNet50(weights='imagenet')

# %%
def classify(image_path):
    display(Image(filename=image_path))
    img = image.load_img(image_path,target_size=(224,224))
    x = image.img_to_array(img)
    x = np.expand_dims(x,axis=0)
    x = preprocess_input(x)
    
    pred = model.predict(x)
    print('Prediction:',decode_predictions(pred,top=3)[0])

# %%
classify('flower.png')
# Out:
# Prediction: [('n11939491', 'daisy', 0.99998283), ('n01819313', 'sulphur-crested_cockatoo', 2.7061478e-06), ('n04286575', 'spotlight', 1.6436563e-06)]

# %%
classify('cycle.png')
# Out:
# Prediction: [('n03792782', 'mountain_bike', 0.88199806), ('n02835271', 'bicycle-built-for-two', 0.072807394), ('n03208938', 'disk_brake', 0.034515847)]

# %%
classify('bag.png')
# Out:
# Prediction: [('n04026417', 'purse', 0.5861409), ('n03709823', 'mailbag', 0.37373325), ('n02769748', 'backpack', 0.033048794)]
